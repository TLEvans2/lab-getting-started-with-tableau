# %% [markdown]
# Load the dataset into a notebook.
#
# Create a barplot of the number of customers per Gender.
#
# Create a barplot of the number of customers per EmploymentStatus and Gender.
#
# Identify Measurements and Dimensions. Are they the same as bthe ones in your Pandas dataframe? Modify accordingly.
#
# Save as unit-4-lab.tbwx.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
display(data.shape)
data.head()
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
gender = data.groupby(['Gender']).agg({'Customer':'count'})

# %%
def discrete_plot(df):
    for column in df.columns:
        sns.countplot(x=column, data=df)
        plt.show()

test = discrete_plot(gender)

# %%
# data.pivot_table(index= ['Gender','Employment Status'], values = ['','Profit','Discount']).reset_index()
df = data.pivot_table(index= ['Gender','EmploymentStatus'], values = ['Customer'], aggfunc = {'Customer':'count'}).reset_index()
df
# Out:
#   Gender EmploymentStatus  Customer
# 0      F         Disabled       244
# 1      F         Employed      2937
# 2      F    Medical Leave       214
# 3      F          Retired       128
# 4      F       Unemployed      1135
# 5      M         Disabled       161
# 6      M         Employed      2761
# 7      M    Medical Leave       218
# 8      M          Retired       154
# 9      M       Unemployed      1182

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Create a bar plot
sns.barplot(x='EmploymentStatus', y='Customer', hue='Gender', data=df)
plt.xlabel('Employment Status')
plt.ylabel('Number of Customers')
plt.title('Number of Customers per Employment Status and Gender')
plt.show()

# %%
data.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
def print_data_type_aliases(df):
    for column_name, data_type in df.dtypes.items():
        if data_type == 'object':
            print(f"{column_name}: Dimension")
        elif data_type == 'float64':
            print(f"{column_name}: Measure")
        else:
            print(f"{column_name}: Dimension")

# %%
print_data_type_aliases(data)
# Out:
# Customer: Dimension
# State: Dimension
# Customer Lifetime Value: Measure
# Response: Dimension
# Coverage: Dimension
# Education: Dimension
# Effective To Date: Dimension
# EmploymentStatus: Dimension
# Gender: Dimension
# Income: Dimension
# Location Code: Dimension
# Marital Status: Dimension
# Monthly Premium Auto: Dimension
# Months Since Last Claim: Dimension
# Months Since Policy Inception: Dimension
# Number of Open Complaints: Dimension
# Number of Policies: Dimension
# Policy Type: Dimension
# Policy: Dimension
# Renew Offer Type: Dimension
# Sales Channel: Dimension
# Total Claim Amount: Measure
# Vehicle Class: Dimension
# Vehicle Size: Dimension
